# %%
#population histogram by country and year

import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_6298256.csv', skiprows=3, header=0)
print(df.columns)

years = df.columns[4:-1]
df_long = pd.melt(df, id_vars=['Country Name', 'Country Code'], value_vars=years, var_name='Year', value_name='Population')
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long = df_long.dropna(subset=['Population', 'Year'])
plt.figure(figsize=(12, 6))
sns.histplot(data=df_long, x='Year', y='Population', hue='Country Name', element='step', stat='density', common_norm=False)
plt.title('Population Histogram by Year and Country')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
# extracting world population of last five years

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_6298256.csv', skiprows=3, header=0)

# Extracting years
years = df.columns[4:-1]

# Extracting world population for the last five years and replacing NaN with zeros
world_population_last_five_years = df.iloc[1, -5:].fillna(0).astype(int)

plt.figure(figsize=(12, 6))
plt.plot(years[-5:], world_population_last_five_years, marker='o', linestyle='-')
plt.title('World Population Over the Last Five Years')
plt.xlabel('Year')
plt.ylabel('Total Population')

# Adding annotations for each point
for i, txt in enumerate(world_population_last_five_years):
    plt.annotate(txt, (years[-5:][i], world_population_last_five_years[i]), textcoords="offset points", xytext=(0,10), ha='center')

plt.show()

# %%
# Population over time

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_6298256.csv', skiprows=3, header=0)

# Extracting years
years = df.columns[4:-1]

world_population = df.iloc[1, 4:-1].astype(int)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(years, world_population, marker='o', linestyle='-')
plt.title('World Population Over Time')
plt.xlabel('Year')
plt.ylabel('Total Population')
plt.show()
